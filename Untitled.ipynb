# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-1.5.3-cp311-cp311-macosx_10_9_x86_64.whl (11.9 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, request, render_template, url_for
import sqlite3
import pandas as pd

def get_df():
    conn = sqlite3.connect('database.sqlite')
    cursor = conn.cursor()
    df = pd.read_sql_query("SELECT * FROM companies", conn)
    conn.close()
    return df

get_df()
# Out:
#                                      name  \
# 0                     Cisco Systems, Inc.
# 1                Motorola Solutions, Inc.
# 2                       Nokia Corporation
# 3     Foxconn Industrial Internet Co. Ltd
# 4      Hewlett Packard Enterprise Company
# ...                                   ...
# 4404               Real Goods Solar, Inc.
# 4405                        Fernhill Corp
# 4406                   Go Solar USA, Inc.
# 4407             Array Technologies, Inc.
# 4408        Solaer Renewable Energies Ltd
#
#                                                    link  \
# 0        https://disfold.com/company/cisco-systems-inc/
# 1     https://disfold.com/company/motorola-solutions...
# 2        https://disfold.com/company/nokia-corporation/
# 3     https://disfold.com/company/foxconn-industrial...
# 4     https://disfold.com/company/hewlett-packard-en...
# ...                                                 ...
# 4404  https://disfold.com/company/real-goods-solar-inc/
# 4405         https://disfold.com/company/fernhill-corp/
# 4406      https://disfold.com/company/go-solar-usa-inc/
# 4407  https://disfold.com/company/array-technologies...
# 4408  https://disfold.com/company/solaer-renewable-e...
#
#                                             description  \
# 0     Cisco Systems, Inc. designs, manufactures, and...
# 1     Motorola Solutions, Inc. provides mission crit...
# 2     Nokia Oyj provides mobile, fixed, and cloud ne...
# 3     Foxconn Industrial Internet Co., Ltd. engages ...
# 4     Hewlett Packard Enterprise Company provides so...
# ...                                                 ...
# 4404  Real Goods Solar, Inc. operates as a residenti...
# 4405  Fernhill Corporation operates as a media, tech...
# 4406  Go Solar USA, Inc. designs, sells, and install...
# 4407  Array Technologies, Inc. manufactures and supp...
# 4408  Solaer Renewable Energies Ltd develops and ins...
#
#                                    site                 category  rank
# 0                 https://www.cisco.com  Communication Equipment     1
# 1     https://www.motorolasolutions.com  Communication Equipment     2
# 2                 https://www.nokia.com  Communication Equipment     3
# 3           https://www.fii-foxconn.com  Communication Equipment     4
# 4                   https://www.hpe.com  Communication Equipment     5
# ...                                 ...                      ...   ...
# 4404          https://www.rgsenergy.com                    Solar    88
# 4405       https://www.fernhillcorp.com                    Solar    89
# 4406      https://www.gosolarusainc.com                    Solar    90
# 4407           https://arraytechinc.com                    Solar    91
# 4408           https://www.solaer.co.il                    Solar    92
#
# [4409 rows x 6 columns]
